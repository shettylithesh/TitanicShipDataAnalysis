# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
dataset=pd.read_csv("C:/Users/Lithesh shetty/Desktop/3rd SEM/3.Statistics_for_Data_Science/Unit 1/Project/titanic1.csv")

# %%
df=pd.DataFrame(dataset)

# %%
df.Sex.value_counts().plot(kind="pie",autopct='%1.0f%%')
plt.show()

# %%
df.Survived.value_counts().plot(kind="pie",autopct='%1.0f%%')
plt.show()

# %%
df.Survived.value_counts().plot(kind="bar")
plt.xlabel("Dead(0)   |    Survived(1)")
plt.ylabel("Number of Peoples")
plt.show()

# %%
df.Embarked.value_counts().plot(kind="bar")
plt.xlabel("Port Of Embarkation\n\nC = Cherbourg; Q = Queenstown; S = Southampton")
plt.ylabel("Number of Peoples")
plt.show()

# %%
df.Pclass.value_counts().plot(kind="bar")
plt.xlabel("Passenger Ticket Class (1st,2nd & 3rd)")
plt.ylabel("Number of Peoples")
plt.show()
plt.show()

# %%
sns.set_style("whitegrid")
sns.barplot(x='Pclass', y='Survived', data=dataset)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Survived'>

# %% [markdown]
# INFERENCE:
# Here we see clearly, that Pclass is contributing to a persons chance of survival,
# especially if a person had bought class 1 ticket then his chances of survival is high

# %%
#scaterplot of fare versus Age
sns.scatterplot(x='Age',y="Fare",data=dataset)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Fare'>

# %% [markdown]
# INFERENCE:
# Based on this chart we also see price trends rising below 300 and older people tend to buy cheap tickets

# %%
#How gender affected a passengers survival
sns.countplot(x="Survived" ,hue="Sex",data=dataset)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %% [markdown]
# INFERENCE : From above plot its clear Among The Survivors
# most of them were females,beacuse females were given high
# priority in the rescue operation

# %%
#the below plot explains how number of passengers survived depended on their ticket class
sns.set_style("whitegrid")
sns.countplot(x="Survived",hue="Pclass",data=dataset)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %% [markdown]
# INFERENC:
# It's quite clear the passengers who had class 1 tickets
# were given priority in resue operation, Most of them
# with class 3 tickets have died(350+)

# %%
numerical_cols=['Age','Parch','SibSp','Fare']
# Normalize continious data
df_norm = df.copy()   
for cols in numerical_cols:
    df_norm[cols] = (df_norm[cols] - df_norm[cols].min())/(df_norm[cols].max() - df_norm[cols].min())
    
df_norm.describe()
# Out:
#        Unnamed: 0  Unnamed: 0.1  PassengerId    Survived      Pclass  \
# count  891.000000    891.000000   891.000000  891.000000  891.000000
# mean   445.000000    445.000000   446.000000    0.383838    2.308642
# std    257.353842    257.353842   257.353842    0.486592    0.836071
# min      0.000000      0.000000     1.000000    0.000000    1.000000
# 25%    222.500000    222.500000   223.500000    0.000000    2.000000
# 50%    445.000000    445.000000   446.000000    0.000000    3.000000
# 75%    667.500000    667.500000   668.500000    1.000000    3.000000
# max    890.000000    890.000000   891.000000    1.000000    3.000000
#
#               Age       SibSp       Parch        Fare
# count  891.000000  891.000000  891.000000  891.000000
# mean     0.373664    0.065376    0.063599    0.062858
# std      0.163790    0.137843    0.134343    0.096995
# min      0.000000    0.000000    0.000000    0.000000
# 25%      0.271174    0.000000    0.000000    0.015440
# ...

# %%
sns.distplot(df_norm['Age'],kde=True)
plt.title("Normal plot of the Age")
plt.figure()
# Out:
# c:\users\lithesh shetty\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df_norm['Fare'],kde=True)
plt.title("Normal plot of the Fare")
plt.figure()
# Out:
# c:\users\lithesh shetty\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df_norm['Parch'],kde=True)
plt.title("Normal plot of the Parch")
plt.figure()
# Out:
# c:\users\lithesh shetty\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df_norm['SibSp'],kde=True)
plt.title("Normal plot of the SibSp")
plt.figure()
# Out:
# c:\users\lithesh shetty\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Standardize numerical columns
df_std = df.copy()
    
for cols in numerical_cols:
    df_std[cols] = (df_std[cols] - df_std[cols].mean())/(df_std[cols].std())
    
df_std.describe()
# Out:
#        Unnamed: 0  Unnamed: 0.1  PassengerId    Survived      Pclass  \
# count  891.000000    891.000000   891.000000  891.000000  891.000000
# mean   445.000000    445.000000   446.000000    0.383838    2.308642
# std    257.353842    257.353842   257.353842    0.486592    0.836071
# min      0.000000      0.000000     1.000000    0.000000    1.000000
# 25%    222.500000    222.500000   223.500000    0.000000    2.000000
# 50%    445.000000    445.000000   446.000000    0.000000    3.000000
# 75%    667.500000    667.500000   668.500000    1.000000    3.000000
# max    890.000000    890.000000   891.000000    1.000000    3.000000
#
#                 Age         SibSp         Parch          Fare
# count  8.910000e+02  8.910000e+02  8.910000e+02  8.910000e+02
# mean   1.116453e-16  3.588600e-17  4.585433e-17 -1.196200e-17
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -2.281359e+00 -4.742788e-01 -4.734077e-01 -6.480577e-01
# ...

# %% [markdown]
# 3.	Discuss why is normalization is needed? How does it affect dataset?
# 1.Increased consistency.
# 2.reducing the possibility of inconsistent data.
# 3.If all the data is made into same units (ie scaled down to value between 0 and 1) then it will be quite good input
# for the machine learning model
